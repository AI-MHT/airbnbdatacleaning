# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import missingno as msno
from geopy.geocoders import Nominatim
from fuzzywuzzy import fuzz
from datetime import datetime
import yagmail

# %% [markdown]
# # Read the CSV file into a Pandas DataFrame

# %%
df = pd.read_csv("C://Users/AI-MHT/Desktop/dataprojet/Airbnb_Open_Data.csv", low_memory=False)

# %% [markdown]
# # Convert column names to lowercase and replace spaces with underscores

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
column_names = df.columns.tolist()
column_names
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_identity_verified',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country_code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room_type',
#  'construction_year',
#  'price',
#  'service_fee',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'review_rate_number',
#  'calculated_host_listings_count',
#  'availability_365',
#  'house_rules',
#  'license']

# %% [markdown]
# # Change the name of column from availability 365 to days_booked

# %%
df.rename(columns={'availability_365': 'days_booked'}, inplace=True)
print("Column renamed from 'availability 365' to 'days_booked'.")
# Out:
# Column renamed from 'availability 365' to 'days_booked'.

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# id                                     0
# name                                 250
# host_id                                0
# host_identity_verified               291
# host_name                            411
# neighbourhood_group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              533
# country_code                         136
# instant_bookable                     110
# cancellation_policy                   76
# room_type                              0
# construction_year                    214
# price                                248
# service_fee                          274
# minimum_nights                       409
# number_of_reviews                    183
# last_review                        15893
# reviews_per_month                  15879
# review_rate_number                   326
# calculated_host_listings_count       319
# days_booked                          448
# house_rules                        52131
# license                           102607
# dtype: int64

# %% [markdown]
# # Visualize missing values using missingno library

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Display the first few rows of the DataFrame

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service_fee minimum_nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...         NaN           30.0
# 2  40.80902 -73.94190            NaN  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number_of_reviews last_review  reviews_per_month review_rate_number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated_host_listings_count  days_booked  \
# 0                            6.0        286.0
# 1                            2.0        228.0
# 2                            1.0        352.0
# 3                            1.0        322.0
# 4                            1.0        289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # Display information about the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102609 entries, 0 to 102608
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102609 non-null  int64
#  1   name                            102359 non-null  object
#  2   host_id                         102609 non-null  int64
#  3   host_identity_verified          102318 non-null  object
#  4   host_name                       102198 non-null  object
#  5   neighbourhood_group             102580 non-null  object
#  6   neighbourhood                   102593 non-null  object
#  7   lat                             102601 non-null  float64
#  8   long                            102601 non-null  float64
#  9   country                         102076 non-null  object
#  10  country_code                    102473 non-null  object
#  11  instant_bookable                102499 non-null  object
#  12  cancellation_policy             102533 non-null  object
#  13  room_type                       102609 non-null  object
#  14  construction_year               102395 non-null  float64
#  15  price                           102361 non-null  object
#  16  service_fee                     102335 non-null  object
#  17  minimum_nights                  102200 non-null  float64
#  18  number_of_reviews               102426 non-null  float64
#  19  last_review                     86716 non-null   object
#  20  reviews_per_month               86730 non-null   float64
#  21  review_rate_number              102283 non-null  float64
#  22  calculated_host_listings_count  102290 non-null  float64
#  23  days_booked                     102161 non-null  float64
#  24  house_rules                     50478 non-null   object
#  25  license                         2 non-null       object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 20.4+ MB

# %% [markdown]
# # Get the shape of the dataset (number of rows and columns)

# %%
df.shape
# Out:
# (102609, 26)

# %% [markdown]
# # Remove duplicate lines

# %%
duplicates = df.duplicated().sum()
df.drop_duplicates(inplace=True)
print("Number of duplicated column ="duplicates)
# Out:
# 551

# %% [markdown]
# # Get the shape of the dataset (number of rows and columns)

# %%
df.shape
# Out:
# (102058, 26)

# %% [markdown]
# # Remove the 'license' column

# %%
df.drop(columns=['license'], inplace=True)

# %% [markdown]
# # Remove the 'lat' and 'long' who are null and save them in new file

# %%
# Filter rows where 'lat' or 'long' is None or NaN
rows_to_check = df[df['lat'].isnull() | df['long'].isnull()| df['review_rate_number'].isnull()| df['reviews_per_month'].isnull()| df['last_review'].isnull()| df['number_of_reviews'].isnull()| df['calculated_host_listings_count'].isnull()| df['host_id'].isnull()]

# Delete rows with missing lat or long values from the original DataFrame
df.dropna(subset=['host_id','lat', 'long','review_rate_number','reviews_per_month','last_review','number_of_reviews','calculated_host_listings_count'], inplace=True)
# Get the current date in the required format (DD_MM_YYYY)
current_date = datetime.now().strftime("%d_%m_%Y")
rows_to_check.to_csv(f'need_to_check_{current_date}.csv', index=False)

# %% [markdown]
# # sending email to agent who is responsable of Geopositioning to correct mistakes

# %%
# def send_email():
#     sender_email = 'ensemdocs@gmail.com'
#     sender_password = 'hqdq iheg repw bpsj'
#     receiver_email = 'aiman.mouhat.info@gmail.com'
#     current_date = datetime.now().strftime("%d_%m_%Y")

#     yag = yagmail.SMTP(sender_email, sender_password)
    
#     file_path = f'need_to_check_{current_date}.csv'
#     subject = f"CSV File - {current_date}"
#     body = "Please find the attached CSV file."

#     yag.send(
#         to=receiver_email,
#         subject=subject,
#         contents=body,
#         attachments=file_path,
#     )

# send_email()

# %% [markdown]
# # Function to update country code based on the country name

# %%
def update_country_code(row):
    if row['country'] == 'United States':
        return 'US'
    else:
        return row['country_code']

# Apply the function to update the country code column
df['country_code'] = df.apply(update_country_code, axis=1)

# %% [markdown]
# # Fill empty 'house_rules' column with specified text

# %%
df['house_rules'] = df['house_rules'].fillna('You should respect our rules mentioned in Airbnb')

# %% [markdown]
# # Fill empty 'days_booked' column with 0

# %%
df['days_booked'].fillna('0', inplace=True)

# %% [markdown]
# # Fill missing values in 'host_identity_verified' column with 'unconfirmed'

# %%
df['host_identity_verified'].fillna('unconfirmed', inplace=True)

# %% [markdown]
# # Define a function to find the most similar neighbourhood group

# %%
def find_neighbourhood_group(neighbourhood):
    # Filter the dataframe for non-empty 'neighbourhood group' values
    filtered_data = df[df['neighbourhood_group'].notnull()]
    
    # Calculate similarity scores between the given neighbourhood and existing neighbourhoods
    similarity_scores = filtered_data['neighbourhood'].apply(lambda x: fuzz.ratio(str(x).lower(), str(neighbourhood).lower()))
    
    # Find the index of the most similar neighbourhood
    max_similarity_index = similarity_scores.idxmax()
    
    # Return the corresponding 'neighbourhood group' value
    return df.loc[max_similarity_index, 'neighbourhood_group']

# Fill missing 'neighbourhood group' values based on 'neighbourhood'
df['neighbourhood_group'] = df.apply(
    lambda row: find_neighbourhood_group(row['neighbourhood']) if pd.isnull(row['neighbourhood_group']) else row['neighbourhood_group'],
    axis=1
)

# %% [markdown]
# # Remove the 'country' column

# %%
df.drop(columns=['country'], inplace=True)

# %% [markdown]
# # Function to check and update the 'name' column

# %%
def update_name(row):
    if pd.isnull(row['name']) or isinstance(row['name'], int):
        return row['room_type']+" for location"
    else:
        return row['name']

# Apply the function to update the 'NAME' column
df['name'] = df.apply(update_name, axis=1)

# %% [markdown]
# # Fill missing 'host name' values with 'host id'

# %%
df['host_name'].fillna(df['host_id'], inplace=True)

# %% [markdown]
# # Fill missing 'instant bookable' values with 'FALSE'

# %%
df['instant_bookable'].fillna('FALSE', inplace=True)

# %% [markdown]
# # Fill missing 'cancellation_policy' values with 'flexible'

# %%
df['cancellation_policy'].fillna('flexible', inplace=True)

# %% [markdown]
# # Replace 'none' or empty values in 'Construction_year' column with 1975

# %%
df['construction_year'].fillna('1975', inplace=True)
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ...  price service_fee minimum_nights  \
# 0  40.64749 -73.97237           US  ...    NaN       $193            10.0
# 1  40.75362 -73.98377           US  ...  $142          NaN           30.0
# 3  40.68514 -73.95976           US  ...  $368         $74            30.0
# 4  40.79851 -73.94399           US  ...  $204         $41            10.0
# 5  40.74767 -73.97500           US  ...  $577        $115             3.0
#
#   number_of_reviews last_review reviews_per_month  review_rate_number  \
# 0               9.0  10/19/2021              0.21                 4.0
# 1              45.0   5/21/2022              0.38                 4.0
# 3             270.0    7/5/2019              4.64                 4.0
# 4               9.0  11/19/2018              0.10                 3.0
# 5              74.0   6/22/2019              0.59                 3.0
#
#    calculated_host_listings_count days_booked  \
# 0                             6.0       286.0
# 1                             2.0       228.0
# 3                             1.0       322.0
# 4                             1.0       289.0
# 5                             1.0       374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3   You should respect our rules mentioned in Airbnb
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %% [markdown]
# # Apply the cleaning function to 'price' and 'service fee' columns removing sepcial charachter

# %%
def clean_currency(column):
    return column.replace({'\$': '', ',': ''}, regex=True).astype(float)

df['price'] = clean_currency(df['price'])
df['service_fee'] = clean_currency(df['service_fee'])
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ...  price service_fee minimum_nights  \
# 0  40.64749 -73.97237           US  ...    NaN       193.0           10.0
# 1  40.75362 -73.98377           US  ...  142.0         NaN           30.0
# 3  40.68514 -73.95976           US  ...  368.0        74.0           30.0
# 4  40.79851 -73.94399           US  ...  204.0        41.0           10.0
# 5  40.74767 -73.97500           US  ...  577.0       115.0            3.0
#
#   number_of_reviews  last_review  reviews_per_month  review_rate_number  \
# 0               9.0   10/19/2021               0.21                 4.0
# 1              45.0    5/21/2022               0.38                 4.0
# 3             270.0     7/5/2019               4.64                 4.0
# 4               9.0   11/19/2018               0.10                 3.0
# 5              74.0    6/22/2019               0.59                 3.0
#
#    calculated_host_listings_count days_booked  \
# 0                             6.0       286.0
# 1                             2.0       228.0
# 3                             1.0       322.0
# 4                             1.0       289.0
# 5                             1.0       374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3   You should respect our rules mentioned in Airbnb
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %%
# if not df['price'].isnull().any():
#     df['service_fee'] = df['price'] * 0.18 + 2
# df.head()

# %% [markdown]
# # adding fees service

# %%
df['service_fee'] = df.apply(lambda row: row['price'] * 0.18 + 2 if pd.isnull(row['service_fee']) else row['service_fee'], axis=1)
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ...  price service_fee minimum_nights  \
# 0  40.64749 -73.97237           US  ...    NaN      193.00           10.0
# 1  40.75362 -73.98377           US  ...  142.0       27.56           30.0
# 3  40.68514 -73.95976           US  ...  368.0       74.00           30.0
# 4  40.79851 -73.94399           US  ...  204.0       41.00           10.0
# 5  40.74767 -73.97500           US  ...  577.0      115.00            3.0
#
#   number_of_reviews  last_review  reviews_per_month  review_rate_number  \
# 0               9.0   10/19/2021               0.21                 4.0
# 1              45.0    5/21/2022               0.38                 4.0
# 3             270.0     7/5/2019               4.64                 4.0
# 4               9.0   11/19/2018               0.10                 3.0
# 5              74.0    6/22/2019               0.59                 3.0
#
#    calculated_host_listings_count days_booked  \
# 0                             6.0       286.0
# 1                             2.0       228.0
# 3                             1.0       322.0
# 4                             1.0       289.0
# 5                             1.0       374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3   You should respect our rules mentioned in Airbnb
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %% [markdown]
# # adding price

# %%
df['price'] = df.apply(lambda row: row['service_fee'] / 0.12 - 2 if pd.isnull(row['price']) else row['price'], axis=1)
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ...        price service_fee  \
# 0  40.64749 -73.97237           US  ...  1606.333333      193.00
# 1  40.75362 -73.98377           US  ...   142.000000       27.56
# 3  40.68514 -73.95976           US  ...   368.000000       74.00
# 4  40.79851 -73.94399           US  ...   204.000000       41.00
# 5  40.74767 -73.97500           US  ...   577.000000      115.00
#
#   minimum_nights number_of_reviews  last_review  reviews_per_month  \
# 0           10.0               9.0   10/19/2021               0.21
# 1           30.0              45.0    5/21/2022               0.38
# 3           30.0             270.0     7/5/2019               4.64
# 4           10.0               9.0   11/19/2018               0.10
# 5            3.0              74.0    6/22/2019               0.59
#
#    review_rate_number  calculated_host_listings_count days_booked  \
# 0                 4.0                             6.0       286.0
# 1                 4.0                             2.0       228.0
# 3                 4.0                             1.0       322.0
# 4                 3.0                             1.0       289.0
# 5                 3.0                             1.0       374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3   You should respect our rules mentioned in Airbnb
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %% [markdown]
# # Round 'price' column values to integers

# %%
def round_float_to_int(column):
    return column.replace([np.inf, -np.inf], np.nan).fillna(0).astype(float).apply(np.floor).astype(int)

df['price'] = round_float_to_int(df['price'])
df['service_fee'] = round_float_to_int(df['service_fee'])
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ... price service_fee minimum_nights  \
# 0  40.64749 -73.97237           US  ...  1606         193           10.0
# 1  40.75362 -73.98377           US  ...   142          27           30.0
# 3  40.68514 -73.95976           US  ...   368          74           30.0
# 4  40.79851 -73.94399           US  ...   204          41           10.0
# 5  40.74767 -73.97500           US  ...   577         115            3.0
#
#   number_of_reviews  last_review  reviews_per_month  review_rate_number  \
# 0               9.0   10/19/2021               0.21                 4.0
# 1              45.0    5/21/2022               0.38                 4.0
# 3             270.0     7/5/2019               4.64                 4.0
# 4               9.0   11/19/2018               0.10                 3.0
# 5              74.0    6/22/2019               0.59                 3.0
#
#    calculated_host_listings_count days_booked  \
# 0                             6.0       286.0
# 1                             2.0       228.0
# 3                             1.0       322.0
# 4                             1.0       289.0
# 5                             1.0       374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3   You should respect our rules mentioned in Airbnb
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %% [markdown]
# # Fill missing 'minimum nights' values with default '1 night'

# %%
df['minimum_nights'].fillna('1', inplace=True)

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ... price service_fee minimum_nights  \
# 0  40.64749 -73.97237           US  ...  1606         193           10.0
# 1  40.75362 -73.98377           US  ...   142          27           30.0
# 3  40.68514 -73.95976           US  ...   368          74           30.0
# 4  40.79851 -73.94399           US  ...   204          41           10.0
# 5  40.74767 -73.97500           US  ...   577         115            3.0
#
#   number_of_reviews  last_review  reviews_per_month review_rate_number  \
# 0               9.0   10/19/2021               0.21                4.0
# 1              45.0    5/21/2022               0.38                4.0
# 3             270.0     7/5/2019               4.64                4.0
# 4               9.0   11/19/2018               0.10                3.0
# 5              74.0    6/22/2019               0.59                3.0
#
#    calculated_host_listings_count days_booked  \
# 0                             6.0       286.0
# 1                             2.0       228.0
# 3                             1.0       322.0
# 4                             1.0       289.0
# 5                             1.0       374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3   You should respect our rules mentioned in Airbnb
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %%
# # Initialize geopy
# geolocator = Nominatim(user_agent="geoapiExercises")

# # Function to get country code using latitude and longitude
# def get_country_code(lat, long):
#     location = geolocator.reverse((lat, long), exactly_one=True)
#     if location is not None:
#         return location.raw.get('address', {}).get('country_code')
#     return None

# # Iterate through the rows and fill missing country codes
# for index, row in df.iterrows():
#     if pd.isnull(row['country code']) or row['country code'] == '':
#         lat = row['lat']
#         long = row['long']
#         country_code = get_country_code(lat, long)
#         country_code = country_code.upper()
#         df.at[index, 'country code'] = country_code

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ... price service_fee minimum_nights  \
# 0  40.64749 -73.97237           US  ...  1606         193           10.0
# 1  40.75362 -73.98377           US  ...   142          27           30.0
# 3  40.68514 -73.95976           US  ...   368          74           30.0
# 4  40.79851 -73.94399           US  ...   204          41           10.0
# 5  40.74767 -73.97500           US  ...   577         115            3.0
#
#   number_of_reviews  last_review  reviews_per_month review_rate_number  \
# 0               9.0   10/19/2021               0.21                4.0
# 1              45.0    5/21/2022               0.38                4.0
# 3             270.0     7/5/2019               4.64                4.0
# 4               9.0   11/19/2018               0.10                3.0
# 5              74.0    6/22/2019               0.59                3.0
#
#    calculated_host_listings_count availability_365  \
# 0                             6.0            286.0
# 1                             2.0            228.0
# 3                             1.0            322.0
# 4                             1.0            289.0
# 5                             1.0            374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3  No rules, you should just respect our rules in...
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %%
# df['last_review'] = pd.to_datetime(df['last_review']).dt.date
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Display the first 5 rows of the cleaned DataFrame

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 3  1002755                      Entire home/apt for location  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long country_code  ... price service_fee minimum_nights  \
# 0  40.64749 -73.97237           US  ...  1606         193           10.0
# 1  40.75362 -73.98377           US  ...   142          27           30.0
# 3  40.68514 -73.95976           US  ...   368          74           30.0
# 4  40.79851 -73.94399           US  ...   204          41           10.0
# 5  40.74767 -73.97500           US  ...   577         115            3.0
#
#   number_of_reviews  last_review  reviews_per_month review_rate_number  \
# 0               9.0   10/19/2021               0.21                4.0
# 1              45.0    5/21/2022               0.38                4.0
# 3             270.0     7/5/2019               4.64                4.0
# 4               9.0   11/19/2018               0.10                3.0
# 5              74.0    6/22/2019               0.59                3.0
#
#    calculated_host_listings_count days_booked  \
# 0                             6.0       286.0
# 1                             2.0       228.0
# 3                             1.0       322.0
# 4                             1.0       289.0
# 5                             1.0       374.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 3   You should respect our rules mentioned in Airbnb
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
# [5 rows x 24 columns]

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_identity_verified             0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                     16
# lat                                0
# long                               0
# country_code                      76
# instant_bookable                   0
# cancellation_policy                0
# room_type                          0
# construction_year                  0
# price                              0
# service_fee                        0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# review_rate_number                 0
# calculated_host_listings_count     0
# days_booked                        0
# house_rules                        0
# dtype: int64

# %% [markdown]
# # Specify the path where you want to save the Excel file

# %%
output_file_path = "C://Users/AI-MHT/Desktop/data/datafinal/Cleaned_Airbnb_Dataxwx.xlsx"

# %% [markdown]
# # Save the cleaned DataFrame to an Excel file

# %%
df.to_excel(output_file_path, index=False)

print(f"Data has been saved to '{output_file_path}'.")
# Out:
# Data has been saved to 'C://Users/AI-MHT/Desktop/data/datafinal/Cleaned_Airbnb_Dataxwx.xlsx'.

# %% [markdown]
# # copy the old template to our new excel file

# %%
# old_template_path = "C://Users/AI-MHT/Desktop/data/datafinal/nadya.xlsx"

# # Check if the old template exists
# if os.path.exists(old_template_path):
#     # Remove the old output file (if it exists)
#     if os.path.exists(output_file_path):
#         os.remove(output_file_path)
    
#     # Copy the old template to the new output file path
#     shutil.copy(old_template_path, output_file_path)
    
#     print(f"Existing Excel file replaced with new content using the old template.")
# else:
#     print(f"Warning: Old template not found at '{old_template_path}'. Make sure the path is correct.")
